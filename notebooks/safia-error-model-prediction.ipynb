# %%
import spreg
from spreg import OLS
from spreg import ML_Error, ML_Error_Regimes
import pysal as ps
import libpysal
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import robust_scale
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from tobler.area_weighted import area_join, area_interpolate

# %%
db = libpysal.io.open('../raw_data/basic_model_preds_gdf.dbf','r')
df = gpd.read_file('../raw_data/basic_model_preds_gdf.shp')

# %%
df.columns
# Out:
# Index(['PLR_ID', 'public_tra', 'eating', 'culture', 'community', 'health_car',
#        'public_ser', 'education', 'universiti', 'outdoor_fa', 'outdoor_le',
#        'night_life', 'water', 'mig_rate', 'ave_rent', 'social_hou',
#        'public_hou', 'five_y_pls', 'child_pov', 'dyn_unempl', 'air', 'bio',
#        'vegpm20', 'ch_rate', 'other_sch', 'vocat_sch', 'primary_sc',
#        'Gymnasium', 'secon_sch', 'priv_schoo', 'kita', 'stations', 'geometry'],
#       dtype='object')

# %%
columns = [
        'public_tra', 'eating', 'culture', 'community', 'health_car',
        'public_ser', 'education', 'universiti', 'outdoor_fa', 'outdoor_le',
        'night_life', 'water', 'mig_rate', 'ave_rent', 'social_hou',
        'public_hou', 'five_y_pls', 'dyn_unempl', 'air', 'bio',
        'vegpm20', 'ch_rate', 'other_sch', 'vocat_sch', 'primary_sc',
        'Gymnasium', 'secon_sch', 'priv_schoo', 'kita', 'stations'
        ]
#regimes = db.by_col("label")

# %%
y = np.array(db.by_col('child_pov')).T
x_names = columns
X = np.array([db.by_col(var) for var in x_names]).T

# %%
X.shape
# Out:
# (536, 30)

# %%
queen = libpysal.weights.Queen.from_dataframe(df)

# %%
inv_dist = libpysal.weights.DistanceBand.from_dataframe(df, 5000, geom_col='geometry', binary=False)

# %%
rook = libpysal.weights.Rook.from_dataframe(df)

# %%
mlerror = ML_Error(y,
                   X,
                   name_x=columns,
                   name_y='child poverty',
                   w=inv_dist,
                   name_ds='selected_ds',
                   name_w='inv_dist')

# %%
print(mlerror.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL ERROR (METHOD = FULL)
# -------------------------------------------------------------------
# Data set            : selected_ds
# Weights matrix      :    inv_dist
# Dependent Variable  :child poverty                Number of Observations:         536
# Mean dependent var  :     24.5406                Number of Variables   :          31
# S.D. dependent var  :     16.6701                Degrees of Freedom    :         505
# Pseudo R-squared    :      0.7890
# Sigma-square ML     :      58.425                Log likelihood        :   -1850.709
# S.E of regression   :       7.644                Akaike info criterion :    3763.419
#                                                  Schwarz criterion     :    3896.227
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      16.0509384       9.1057585       1.7627239       0.0779471
#           public_tra      -0.0024871       0.0120127      -0.2070364       0.8359814
#               eating      -0.0670518       0.0144039      -4.6551230       0.0000032
#              culture      -0.0791092       0.1423827      -0.5556098       0.5784777
#            community       0.4288004       0.1973803       2.1724576       0.0298212
#           health_car       0.0167294       0.0186673       0.8961895       0.3701515
#           public_ser      -0.0223220       0.0787082      -0.2836047       0.7767134
#            education      -1.0090004       0.3359668      -3.0032744       0.0026709
#           universiti       0.0884790       0.3506713       0.2523131       0.8007990
#           outdoor_fa      -0.0035996       0.0037480      -0.9603992       0.3368544
#           outdoor_le      -0.0394648       0.0536209      -0.7359965       0.4617328
#           night_life       0.1316832       0.0453400       2.9043497       0.0036802
#                water      -0.0732988       0.1418012      -0.5169123       0.6052174
#             mig_rate      60.0050834       4.1371321      14.5040287       0.0000000
#             ave_rent      -0.9638047       0.2555343      -3.7717238       0.0001621
#           social_hou       0.0837463       0.0916457       0.9138044       0.3608196
#           public_hou       0.1661070       0.0396839       4.1857568       0.0000284
#           five_y_pls      -0.1576639       0.1104575      -1.4273710       0.1534730
#           dyn_unempl       5.7970880       0.4751498      12.2005489       0.0000000
#                  air       0.5699784       0.7546775       0.7552608       0.4500925
#                  bio       2.2204365       0.7637557       2.9072603       0.0036461
#              vegpm20      -0.2441694       0.1961573      -1.2447635       0.2132187
#              ch_rate       0.0961319       0.0197390       4.8701532       0.0000011
#            other_sch      -1.0397076       3.0114052      -0.3452566       0.7299015
#            vocat_sch      -0.5744643       0.5612820      -1.0234859       0.3060781
#           primary_sc      -0.0735192       0.2887936      -0.2545736       0.7990525
#            Gymnasium      -0.3498847       0.4590476      -0.7621970       0.4459425
#            secon_sch       0.8443094       0.4334260       1.9479897       0.0514162
#           priv_schoo      -0.0092530       0.2442656      -0.0378810       0.9697826
#                 kita      -0.0546078       0.0511200      -1.0682281       0.2854176
#             stations      -0.0315803       0.0906745      -0.3482823       0.7276282
#               lambda       1.0000000       7.9595886       0.1256346       0.9000212
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
# Adding a resituals column to sample dataframe
res = df[['PLR_ID', 'geometry']]
res['residuals_mlerror'] =mlerror.u
# plotting residuals - red = underestimation, blue = overestimation
res.plot('residuals_mlerror', figsize=(15,10), cmap= 'seismic', legend=True)
# Out:
# /Users/Safia/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# <AxesSubplot:>

# %%
west = gpd.read_file('../raw_data/more_maps/Ortsteile__Berlin_West_EPSG54030.shp')
east = gpd.read_file('../raw_data/more_maps/Ortsteile__Berlin_Ost_EPSG54030.shp')

east.to_crs(crs='EPSG:25833', inplace=True)

west.to_crs(crs='EPSG:25833', inplace=True)

west = west.dissolve()

east = east.dissolve()

eastwest = east.append(west)

eastwest['east'] = eastwest.OBJECTID.map({1:1,
                                             2:0})
# Out:
# /var/folders/sx/4s_zvfwj1xddph7py3s74ych0000gn/T/ipykernel_23285/1633683294.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   eastwest = east.append(west)

# %%
df_east = df.sjoin_nearest(
    eastwest, how='left').dissolve(
    by='PLR_ID')

df = df.merge(df_east.reset_index()[['PLR_ID','east']], on='PLR_ID')

# %%
mlerror_regimes = ML_Error_Regimes(y,
                   X,
                    regimes=df['east'],
                   name_x=columns,
                   name_y='child poverty',
                   w=inv_dist,
                   name_ds='selected_ds',
                   name_w='inv_dist')
# Out:
# /Users/Safia/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/scipy/optimize/_minimize.py:870: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   warn("Method 'bounded' does not support relative tolerance in x; "

# %%
print(mlerror_regimes.summary) # only significant difference in the coefficients is in green volume
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: MAXIMUM LIKELIHOOD SPATIAL ERROR - REGIMES (METHOD = full)
# -----------------------------------------------------------------------------
# Data set            : selected_ds
# Weights matrix      :    inv_dist
# Dependent Variable  :child poverty                Number of Observations:         536
# Mean dependent var  :     24.5406                Number of Variables   :          62
# S.D. dependent var  :     16.6701                Degrees of Freedom    :         474
# Pseudo R-squared    :      0.8063
# Sigma-square ML     :      53.663                Log likelihood        :   -1827.942
# S.E of regression   :       7.326                Akaike info criterion :    3779.883
#                                                  Schwarz criterion     :    4045.500
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#         1_night_life       0.1487957       0.0548111       2.7147027       0.0066335
#              1_water      -0.0126316       0.1602448      -0.0788268       0.9371704
#           1_mig_rate      58.9915766       5.3752085      10.9747513       0.0000000
#           1_ave_rent      -1.0144398       0.3394481      -2.9884970       0.0028035
#         1_social_hou       0.1006764       0.1032848       0.9747450       0.3296868
#         1_public_hou       0.1421362       0.0486012       2.9245406       0.0034497
#         1_five_y_pls      -0.1777319       0.1333131      -1.3331912       0.1824691
#         1_dyn_unempl       5.4642100       0.5712244       9.5657854       0.0000000
#                1_air       1.0579876       0.9699322       1.0907851       0.2753674
#                1_bio       2.5932330       0.9952766       2.6055400       0.0091730
#            1_vegpm20       0.1840332       0.2775287       0.6631141       0.5072575
#            1_ch_rate       0.1068659       0.0215435       4.9604632       0.0000007
#          1_other_sch       2.9665535       3.9278080       0.7552695       0.4500873
#          1_vocat_sch      -1.3044464       0.7022275      -1.8575838       0.0632281
#         1_primary_sc      -0.2509352       0.3555488      -0.7057686       0.4803321
#          1_Gymnasium      -0.4334344       0.6617727      -0.6549597       0.5124937
#          1_secon_sch       0.3835081       0.4953724       0.7741814       0.4388235
#         1_priv_schoo       0.1898630       0.2835066       0.6696951       0.5030522
#               1_kita      -0.0705139       0.0624189      -1.1296886       0.2586075
#           1_stations      -0.0714955       0.1002958      -0.7128468       0.4759406
#               lambda       1.0000000       7.9595886       0.1256346       0.9000212
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT         1           1.427           0.2323
#                 Gymnasium         1           0.145           0.7038
#                       air         1           2.330           0.1269
#                  ave_rent         1           0.016           0.8984
#                       bio         1           1.612           0.2042
#                   ch_rate         1           1.400           0.2367
#                 community         1           1.920           0.1659
#                   culture         1           0.413           0.5204
#                dyn_unempl         1           1.032           0.3096
#                    eating         1           0.731           0.3925
#                 education         1           2.097           0.1476
#                five_y_pls         1           1.970           0.1605
#                health_car         1           0.263           0.6078
#                      kita         1           0.011           0.9179
#                  mig_rate         1           3.014           0.0825
#                night_life         1           0.692           0.4053
#                 other_sch         1           0.614           0.4334
#                outdoor_fa         1           0.995           0.3185
#                outdoor_le         1           0.926           0.3358
#                primary_sc         1           4.270           0.0388
#                priv_schoo         1           1.620           0.2032
#                public_hou         1           0.262           0.6085
#                public_ser         1           0.279           0.5973
#                public_tra         1           1.872           0.1712
#                 secon_sch         1           0.953           0.3290
#                social_hou         1           1.747           0.1863
#                  stations         1           0.017           0.8959
#                universiti         1           0.111           0.7394
#                   vegpm20         1           2.665           0.1026
#                 vocat_sch         1           0.990           0.3197
#                     water         1           3.151           0.0759
#               Global test        31          47.528           0.0292
# ================================ END OF REPORT =====================================

# %%
mae(df.child_pov, mlerror.u)
# Out:
# 24.5666732857316

# %%
# Adding a resituals column to sample dataframe
df['residuals_mlerror_reg'] = mlerror_regimes.u

# plotting residuals - red = underestimation, blue = overestimation
df.plot('residuals_mlerror_reg', figsize=(15,10), cmap= 'seismic', legend=True)
