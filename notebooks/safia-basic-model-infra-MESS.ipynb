# %%
from spreg import OLS, vif, OLS_Regimes
import pysal as ps
import libpysal
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from tobler.area_weighted import area_join, area_interpolate
from pysal.explore import esda
import contextily
from sklearn.preprocessing import RobustScaler
from esda.moran import Moran, Moran_Local
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/Safia/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/spaghetti/network.py:36: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(f"{dep_msg}", FutureWarning)

# %%
selected = gpd.read_file('../raw_data/infra_model_gdf.shp')

# %%
selected.columns
# Out:
# Index(['PLR_ID', 'culture', 'outdoor_fa', 'outdoor_le', 'social_hou',
#        'public_hou', 'child_pov', 'vegpm20', 'Gymnasium', 'kita', 'stations',
#        'extra_edu', 'geometry'],
#       dtype='object')

# %%
m = Moran(selected.child_pov, w=inv_dist)

# %%
m.EI
# Out:
# -0.001869158878504673

# %%
error_clusters = m.q % 2 == 1
# Filter out non-significant clusters
error_clusters &= m.p_sim <= 0.001
# Add `error_clusters` and `local_I` columns
ax = (
    selected.assign(
        error_clusters=error_clusters,
        local_I=m.Is
        # Retain error clusters only
    )
    .query(
        "error_clusters"
        # Sort by I value to largest plot on top
    )
    .sort_values(
        "local_I"
        # Plot I values
    )
    .plot("local_I", cmap="bwr", marker=".", figsize=(15,10))
)
# Add basemap
contextily.add_basemap(ax, crs=selected.crs)
# Remove axes
ax.set_axis_off();

# %%
selected = gpd.read_file('../YouthInTheCity/data/cluster_gdf.shp')

# %%
corr = selected.corr()
corr_df = corr.unstack().reset_index() #Unstack correlation matrix
corr_df.columns = ["feature_1", "feature_2", "correlation"] #Rename the columns
corr_df.sort_values(by="correlation", ascending=False, inplace=True)
corr_df = corr_df[corr_df["feature_1"] != corr_df["feature_2"]] #remove the self-corr
corr_df.head(50)
# Out:
#        feature_1   feature_2  correlation
# 3104   child_pov     welfare     0.967386
# 3037     welfare   child_pov     0.967386
# 2830       sales   dyn_sales     0.964766
# 2897   dyn_sales       sales     0.964766
# 1103    E_E15U18     E_E6U15     0.958660
# 1036     E_E6U15    E_E15U18     0.958660
# 3035     welfare  unemployme     0.956929
# 2968  unemployme     welfare     0.956929
# 2969  unemployme   child_pov     0.943110
# 3103   child_pov  unemployme     0.943110
# 965       E_E1U6       E_EU1     0.931663
# 898        E_EU1      E_E1U6     0.931663
# 1034     E_E6U15      E_E1U6     0.925593
# 967       E_E1U6     E_E6U15     0.925593
# 902        E_EU1    E_E25U55     0.900845
# 1237    E_E25U55       E_EU1     0.900845
# 750   night_life      eating     0.862194
# 147       eating  night_life     0.862194
# 1238    E_E25U55      E_E1U6     0.860003
# 970       E_E1U6    E_E25U55     0.860003
# 1379    E_E65U80    E_E55U65     0.852993
# 1312    E_E55U65    E_E65U80     0.852993
# 2692  rent_to_pr  dyn_r_to_p     0.851470
# 2759  dyn_r_to_p  rent_to_pr     0.851470
# 2136    HK_NZOrd     HK_Turk     0.850887
# 1935     HK_Turk    HK_NZOrd     0.850887
# 968       E_E1U6    E_E15U18     0.847805
# 1102    E_E15U18      E_E1U6     0.847805
# 139       eating     culture     0.839034
# 206      culture      eating     0.839034
# 969       E_E1U6    E_E18U25     0.837334
# 1170    E_E18U25      E_E1U6     0.837334
# 1381    E_E65U80   E_E80U110     0.832838
# 1448   E_E80U110    E_E65U80     0.832838
# 1174    E_E18U25    E_E25U55     0.820248
# 1241    E_E25U55    E_E18U25     0.820248
# 1172    E_E18U25    E_E15U18     0.811043
# 1105    E_E15U18    E_E18U25     0.811043
# 2896   dyn_sales  dyn_r_to_p     0.810830
# 2762  dyn_r_to_p   dyn_sales     0.810830
# 1169    E_E18U25       E_EU1     0.808439
# 901        E_EU1    E_E18U25     0.808439
# 215      culture  night_life     0.806965
# 751   night_life     culture     0.806965
# 2828       sales  dyn_r_to_p     0.801509
# 2761  dyn_r_to_p       sales     0.801509
# 1037     E_E6U15    E_E18U25     0.800980
# 1171    E_E18U25     E_E6U15     0.800980
# 2970  unemployme  dyn_unempl     0.798758
# 3171  dyn_unempl  unemployme     0.798758

# %%
f, axs = plt.subplots(figsize=(15, 10))
selected.apply(
    lambda x: ax.annotate(text=x['BZR_NAME'], 
    xy=x.geometry.centroid.coords[0], ha='center'), axis=1);
selected.plot(ax=ax,column='PLR_ID')
# Out:
# <AxesSubplot:>

# %%
selected.BZR_NAME.nunique()
# Out:
# 142

# %%
selected[['PLR_ID', 'BZR_NAME', 'geometry']][selected.child_pov>50].plot(x=selected.BZR_NAME)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 selected[['PLR_ID', 'BZR_NAME', 'geometry']][selected.child_pov>50].plot(x=selected.BZR_NAME)
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/geopandas/plotting.py:963, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     961 kind = kwargs.pop("kind", "geo")
#     962 if kind == "geo":
# --> 963     return plot_dataframe(data, *args, **kwargs)
#     964 if kind in self._pandas_kinds:
#     965     # Access pandas plots
#     966     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/geopandas/plotting.py:704, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     701     markersize = df[markersize].values
#     703 if column is None:
# --> 704     return plot_series(
#     705         df.geometry,
#     706         cmap=cmap,
#     707         color=color,
#     708         ax=ax,
#     709         figsize=figsize,
#     710         markersize=markersize,
#     711         aspect=aspect,
#     712         **style_kwds,
#     713     )
#     715 # To accept pd.Series and np.arrays as column
#     716 if isinstance(column, (np.ndarray, pd.Series)):
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/geopandas/plotting.py:458, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     455         facecolor = color_
#     457     values_ = values[poly_idx] if cmap else None
# --> 458     _plot_polygon_collection(
#     459         ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     460     )
#     462 # plot all LineStrings and MultiLineString components in same collection
#     463 lines = expl_series[line_idx]
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/geopandas/plotting.py:174, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     170     kwargs["color"] = color
#     172 _expand_kwargs(kwargs, multiindex)
# --> 174 collection = PatchCollection(
#     175     [_PolygonPatch(poly) for poly in geoms if not poly.is_empty], **kwargs
#     176 )
#     178 if values is not None:
#     179     collection.set_array(np.asarray(values))
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/collections.py:1848, in PatchCollection.__init__(self, patches, match_original, **kwargs)
#    1845     kwargs['linestyles'] = [p.get_linestyle() for p in patches]
#    1846     kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
# -> 1848 super().__init__(**kwargs)
#    1850 self.set_paths(patches)
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/collections.py:217, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     214 self._transOffset = transOffset
#     216 self._path_effects = None
# --> 217 self.update(kwargs)
#     218 self._paths = None
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/artist.py:1067, in Artist.update(self, props)
#    1065             func = getattr(self, f"set_{k}", None)
#    1066             if not callable(func):
# -> 1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
#    1069             ret.append(func(v))
#    1070 if ret:
#
# AttributeError: 'PatchCollection' object has no property 'x'

# %%
# Load regression gds 

selected = gpd.read_file('../YouthInTheCity/data/regression_gdf.shp')

# Select features manually

selected['extra_edu']=selected.loc[:,'education']

selected.drop(columns=['schools', 'universiti', 'kindergart','HK_EU15', 'HK_EU28', 'HK_Polen', 'HK_EheJug', 'HK_EheSU', 'HK_Turk',
              'schools', 'universiti','kindergart','night_life',
                       'mig_rate','HK_Arab', 'HK_Sonst', 'HK_NZOrd', 'BZR_NAME', 
              'noise',  'health_car', 'vegpm10', 'change','ch_rate',
            'public_tra', 'green' ,'other_sch', 'secon_sch','vocat_sch',
                'sp_nee_sch', 'community','night_life', 'water',  'ave_rent',
              'public_ser','dyn_ew', 'dyn_unempl', 'priv_schoo', 'primary_sc',
                        'five_y_pls', 'dyn_sales','air', 'education','eating','bio'], inplace=True)

# Export it as shapefile
selected.to_file('../raw_data/infra_model_gdf.shp', mode="w")

# Load it again
selected = gpd.read_file('../raw_data/infra_model_gdf.shp')

# %%
selected
# Out:
#        PLR_ID  culture  outdoor_fa  outdoor_le  social_hou  public_hou  \
# 0    11501341      2.0       224.0         8.0    1.302637   24.830919
# 1     3701659     12.0       130.0        10.0    0.390507   12.771489
# 2     7601340      1.0         4.0         6.0   12.720000   26.730000
# 3     2500831      7.0       221.0        14.0    0.740000    8.370000
# 4    12601134      0.0        85.0        24.0    1.560000   42.230000
# ..        ...      ...         ...         ...         ...         ...
# 531  12500927      0.0        61.0         9.0    1.560000   42.230000
# 532   3200204      0.0        75.0         8.0    3.209599    3.458242
# 533  10400941      1.0        45.0         4.0    0.550044    0.751582
# 534   8100101     18.0       342.0         1.0    6.729473    9.548275
# 535  11300616      0.0       156.0         2.0    0.594239   32.749032
#
#      child_pov   vegpm20  Gymnasium  kita  stations  extra_edu  \
# 0         2.58  3.456812        0.0  20.0      10.0        1.0
# 1         8.13  2.896211        1.0  47.0      13.0        6.0
# 2        41.68  2.648765        0.0  17.0       0.0        0.0
# 3        21.15  2.706697        2.0  41.0      13.0        2.0
# 4        51.53  3.861459        1.0  24.0       2.0        1.0
# ..         ...       ...        ...   ...       ...        ...
# 531      20.69  5.223326        2.0  27.0       4.0        0.0
# 532       4.24  3.389884        0.0   7.0       2.0        0.0
# 533       2.89  2.551829        0.0  12.0      12.0        0.0
# 534      40.42  6.286957        1.0  47.0       3.0        2.0
# 535      48.94  4.519987        1.0  11.0      13.0        0.0
#
#                                               geometry
# 0    POLYGON ((399848.954 5815619.506, 399854.727 5...
# 1    POLYGON ((393175.012 5821135.577, 393167.174 5...
# 2    POLYGON ((388394.110 5807792.070, 388379.276 5...
# 3    POLYGON ((396010.552 5819339.570, 396021.567 5...
# 4    POLYGON ((387367.428 5828619.763, 387315.862 5...
# ..                                                 ...
# 531  POLYGON ((387280.650 5828614.114, 387266.882 5...
# 532  POLYGON ((392586.179 5829994.574, 392586.626 5...
# 533  POLYGON ((406064.851 5815581.891, 406061.455 5...
# 534  POLYGON ((391887.140 5816592.598, 391898.686 5...
# 535  POLYGON ((395625.330 5821110.205, 395642.331 5...
#
# [536 rows x 13 columns]

# %%
# loading dbf
db = libpysal.io.open('../raw_data/infra_model_gdf.dbf','r')

# computing spatial weights
queen = libpysal.weights.Queen.from_dataframe(selected)
inv_dist = libpysal.weights.DistanceBand.from_dataframe(selected, 5000, geom_col='geometry', binary=False)
rook = libpysal.weights.Rook.from_dataframe(selected)

# %%
corr = selected.corr()
corr_df = corr.unstack().reset_index() #Unstack correlation matrix
corr_df.columns = ["feature_1", "feature_2", "correlation"] #Rename the columns
corr_df.sort_values(by="correlation", ascending=False, inplace=True)
corr_df = corr_df[corr_df["feature_1"] != corr_df["feature_2"]] #remove the self-corr
corr_df.head(20)
# Out:
#       feature_1   feature_2  correlation
# 21      culture        kita     0.631574
# 109        kita     culture     0.631574
# 119        kita   extra_edu     0.585532
# 141   extra_edu        kita     0.585532
# 14      culture  outdoor_fa     0.447399
# 25   outdoor_fa     culture     0.447399
# 122    stations  outdoor_fa     0.421796
# 34   outdoor_fa    stations     0.421796
# 23      culture   extra_edu     0.401098
# 133   extra_edu     culture     0.401098
# 60   public_hou      PLR_ID     0.397318
# 5        PLR_ID  public_hou     0.397318
# 33   outdoor_fa        kita     0.385805
# 110        kita  outdoor_fa     0.385805
# 76    child_pov  social_hou     0.377728
# 54   social_hou   child_pov     0.377728
# 22      culture    stations     0.375253
# 121    stations     culture     0.375253
# 105   Gymnasium        kita     0.365860
# 116        kita   Gymnasium     0.365860

# %%
y = np.array(selected['child_pov'])
X = selected.drop(columns=[
    'PLR_ID','child_pov', 'geometry']).to_numpy()

# %%
robust = RobustScaler()

# %%
X = robust.fit_transform(X)

# %%
X
# Out:
# array([[ 0.2       ,  0.67820069,  0.25      , ...,  0.04545455,
#          1.        ,  1.        ],
#        [ 2.2       ,  0.02768166,  0.5       , ...,  1.27272727,
#          1.5       ,  6.        ],
#        [ 0.        , -0.84429066,  0.        , ..., -0.09090909,
#         -0.66666667,  0.        ],
#        ...,
#        [ 0.        , -0.56055363, -0.25      , ..., -0.31818182,
#          1.33333333,  0.        ],
#        [ 3.4       ,  1.49480969, -0.625     , ...,  1.27272727,
#         -0.16666667,  2.        ],
#        [-0.2       ,  0.20761246, -0.5       , ..., -0.36363636,
#          1.5       ,  0.        ]])

# %%
columns = [
        'culture', 'outdoor_fa', 'outdoor_le', 'social_hou',
        'public_hou', 'vegpm20', 'Gymnasium', 'kita', 'stations',
        'extra_edu'
]

# %%
m1 = OLS(y,
        X,
        w=inv_dist,
        name_y='child_pov',
        name_x=columns,
        name_w='dist',
        name_ds='basic_model',
        white_test=True,
        gwk=inv_dist,
        spat_diag=True,
        moran=True)

# %%
plt.hist(m1.predy.flatten())
# Out:
# (array([ 14.,  58.,  92., 126., 109.,  90.,  31.,   7.,   3.,   6.]),
#  array([ 0.8236552 ,  6.9010344 , 12.97841361, 19.05579281, 25.13317202,
#         31.21055122, 37.28793043, 43.36530964, 49.44268884, 55.52006805,
#         61.59744725]),
#  <BarContainer object of 10 artists>)

# %%
selected['child_pov'].hist()
# Out:
# <AxesSubplot:>

# %%
mae(selected['child_pov'], m1.predy.flatten())
# Out:
# 10.502076260567257

# %%
mse(selected['child_pov'], m1.predy)
# Out:
# 177.50079323920716

# %%
np.sqrt(mse(selected['child_pov'], m1.predy.flatten()))
# Out:
# 13.322942364177935

# %%
print(m1.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            : basic_model
# Weights matrix      :        dist
# Dependent Variable  :   child_pov                Number of Observations:         536
# Mean dependent var  :     24.5406                Number of Variables   :          11
# S.D. dependent var  :     16.6701                Degrees of Freedom    :         525
# R-squared           :      0.3601
# Adjusted R-squared  :      0.3479
# Sum squared residual:   95140.425                F-statistic           :     29.5401
# Sigma-square        :     181.220                Prob(F-statistic)     :   4.571e-45
# S.E. of regression  :      13.462                Log likelihood        :   -2148.516
# Sigma-square ML     :     177.501                Akaike info criterion :    4319.033
# S.E of regression ML:     13.3229                Schwarz criterion     :    4366.158
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      23.1836403       0.8940718      25.9304006       0.0000000
#              culture       0.2288017       0.7794070       0.2935587       0.7692112
#           outdoor_fa       1.5021663       0.8116532       1.8507490       0.0647672
#           outdoor_le      -0.9233256       0.6923133      -1.3336817       0.1828865
#           social_hou       5.0944012       0.6868126       7.4174550       0.0000000
#           public_hou       8.4410627       0.8496071       9.9352547       0.0000000
#              vegpm20      -1.5661674       0.5458515      -2.8692189       0.0042806
#            Gymnasium      -1.1617814       0.7630489      -1.5225517       0.1284730
#                 kita       7.8084670       1.3192609       5.9188192       0.0000000
#             stations      -4.2782146       0.8002174      -5.3463154       0.0000001
#            extra_edu      -1.8235077       0.4877068      -3.7389425       0.0002051
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER            3.850
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          23.486           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               10          17.310           0.0678
# Koenker-Bassett test             10          15.298           0.1216
#
# SPECIFICATION ROBUST TEST
# TEST                             DF        VALUE           PROB
# White                            65          89.944           0.0220
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.1086        16.081           0.0000
# Lagrange Multiplier (lag)         1         117.284           0.0000
# Robust LM (lag)                   1          50.961           0.0000
# Lagrange Multiplier (error)       1         140.374           0.0000
# Robust LM (error)                 1          74.052           0.0000
# Lagrange Multiplier (SARMA)       2         191.335           0.0000
#
# ================================ END OF REPORT =====================================

# %%
# creating vif dataframe

v = vif(m1)
del(v[0])
vif_array = np.array(v, dtype=float)

v_d = pd.DataFrame({'feature': columns, 
                   'vif': vif_array[:,0], 
                   'tolerance':  vif_array[:,1]})

v_d
# Out:
#       feature       vif  tolerance
# 0     culture  2.046572   0.488622
# 1  outdoor_fa  1.605890   0.622708
# 2  outdoor_le  1.205693   0.829398
# 3  social_hou  1.266336   0.789680
# 4  public_hou  1.309245   0.763799
# 5     vegpm20  1.131491   0.883790
# 6   Gymnasium  1.216399   0.822098
# 7        kita  2.456212   0.407131
# 8    stations  1.653586   0.604746
# 9   extra_edu  1.710570   0.584601

# %%
mae(selected.child_pov, m1.predy)
# Out:
# 10.502076260567264

# %%
mse(selected.child_pov, m1.predy)
# Out:
# 177.50079323920716

# %%
# Adding a resituals column to sample dataframe
res = selected[['PLR_ID', 'geometry']]
res['residuals'] = m1.u

# plotting residuals - red = underestimation, blue = overestimation
#res.plot('residuals', figsize=(15,10), cmap= 'seismic', legend=True)

# %%
from matplotlib import colors
divnorm=colors.TwoSlopeNorm(vmin=-35., vcenter=0., vmax=45)
plt.pcolormesh(res[['residuals', 'geometry']], cmap="seismic", norm=divnorm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       1 from matplotlib import colors
#       2 divnorm=colors.TwoSlopeNorm(vmin=-35., vcenter=0., vmax=45)
# ----> 3 plt.pcolormesh(res[['residuals', 'geometry']], cmap="seismic", norm=divnorm)
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/pyplot.py:2728, in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2723 @_copy_docstring_and_deprecators(Axes.pcolormesh)
#    2724 def pcolormesh(
#    2725         *args, alpha=None, norm=None, cmap=None, vmin=None,
#    2726         vmax=None, shading=None, antialiased=False, data=None,
#    2727         **kwargs):
# -> 2728     __ret = gca().pcolormesh(
#    2729         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2730         vmax=vmax, shading=shading, antialiased=antialiased,
#    2731         **({"data": data} if data is not None else {}), **kwargs)
#    2732     sci(__ret)
#    2733     return __ret
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6072, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6068 C = C.ravel()
#    6070 kwargs.setdefault('snap', rcParams['pcolormesh.snap'])
# -> 6072 collection = mcoll.QuadMesh(
#    6073     coords, antialiased=antialiased, shading=shading,
#    6074     array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    6075 collection._scale_norm(norm, vmin, vmax)
#    6076 self._pcolor_grid_deprecation_helper()
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/collections.py:2015, in QuadMesh.__init__(self, *args, **kwargs)
#    2012 self._bbox.update_from_data_xy(self._coordinates.reshape(-1, 2))
#    2013 # super init delayed after own init because array kwarg requires
#    2014 # self._coordinates and self._shading
# -> 2015 super().__init__(**kwargs)
#    2016 self.mouseover = False
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/collections.py:217, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     214 self._transOffset = transOffset
#     216 self._path_effects = None
# --> 217 self.update(kwargs)
#     218 self._paths = None
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/artist.py:1069, in Artist.update(self, props)
#    1066             if not callable(func):
#    1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
# -> 1069             ret.append(func(v))
#    1070 if ret:
#    1071     self.pchanged()
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/collections.py:2077, in QuadMesh.set_array(self, A)
#    2072     if faulty_data:
#    2073         raise TypeError(
#    2074             f"Dimensions of A {A.shape} are incompatible with "
#    2075             f"X ({width}) and/or Y ({height})")
# -> 2077 return super().set_array(A)
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/matplotlib/cm.py:477, in ScalarMappable.set_array(self, A)
#     475 A = cbook.safe_masked_invalid(A, copy=True)
#     476 if not np.can_cast(A.dtype, float, "same_kind"):
# --> 477     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     478                     "converted to float")
#     480 self._A = A
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
import matplotlib as mpl
class MidpointNormalize(mpl.colors.Normalize):
    def _init_(self, vmin, vmax, midpoint=0, clip=False):
        self.midpoint = midpoint
        mpl.colors.Normalize._init_(self, vmin, vmax, clip)
    def _call_(self, value, clip=None):
        normalized_min = max(0, 1 / 2 * (1 - abs((self.midpoint - self.vmin) / (self.midpoint - self.vmax))))
        normalized_max = min(1, 1 / 2 * (1 + abs((self.vmax - self.midpoint) / (self.midpoint - self.vmin))))
        normalized_mid = 0.5
        x, y = [self.vmin, self.midpoint, self.vmax], [normalized_min, normalized_mid, normalized_max]
        return np.ma.masked_array(np.interp(value, x, y))
#here goes residuals column
vals = res.residuals
vmin = min(res.residuals)
vmax = max(res.residuals)
norm = MidpointNormalize(vmin=vmin, vmax=vmax, midpoint=0)
res.plot(figsize = (12,12), column='residuals', cmap='seismic', norm=norm, legend=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 16>()
#      14 vmin = min(res.residuals)
#      15 vmax = max(res.residuals)
# ---> 16 norm = MidpointNormalize(vmin=vmin, vmax=vmax, midpoint=0)
#      17 res.plot(figsize = (12,12), column='residuals', cmap='seismic', norm=norm, legend=True)
#      18 plt.show()
#
# TypeError: __init__() got an unexpected keyword argument 'midpoint'

# %%
# instantiating knn
knn = libpysal.weights.KNN.from_dataframe(selected, k=5)
# Row standardise weights
knn.transform = "R"
# Run LISA on residuals
outliers = esda.moran.Moran_Local(m1.u, knn, permutations=9999)
# Select only LISA cluster cores
error_clusters = outliers.q % 2 == 1
# Filter out non-significant clusters
error_clusters &= outliers.p_sim <= 0.001
# Add `error_clusters` and `local_I` columns
ax = (
    selected.assign(
        error_clusters=error_clusters,
        local_I=outliers.Is
        # Retain error clusters only
    )
    .query(
        "error_clusters"
        # Sort by I value to largest plot on top
    )
    .sort_values(
        "local_I"
        # Plot I values
    )
    .plot("local_I", cmap="bwr", marker=".", figsize=(15,10))
)
# Add basemap
contextily.add_basemap(ax, crs=selected.crs)
# Remove axes
ax.set_axis_off();

# %%
selected
# Out:
#        PLR_ID  culture  outdoor_fa  outdoor_le  social_hou  public_hou  \
# 0    11501341      2.0       224.0         8.0    1.302637   24.830919
# 1     3701659     12.0       130.0        10.0    0.390507   12.771489
# 2     7601340      1.0         4.0         6.0   12.720000   26.730000
# 3     2500831      7.0       221.0        14.0    0.740000    8.370000
# 4    12601134      0.0        85.0        24.0    1.560000   42.230000
# ..        ...      ...         ...         ...         ...         ...
# 531  12500927      0.0        61.0         9.0    1.560000   42.230000
# 532   3200204      0.0        75.0         8.0    3.209599    3.458242
# 533  10400941      1.0        45.0         4.0    0.550044    0.751582
# 534   8100101     18.0       342.0         1.0    6.729473    9.548275
# 535  11300616      0.0       156.0         2.0    0.594239   32.749032
#
#      child_pov   vegpm20  Gymnasium  kita  stations  extra_edu  \
# 0         2.58  3.456812        0.0  20.0      10.0        1.0
# 1         8.13  2.896211        1.0  47.0      13.0        6.0
# 2        41.68  2.648765        0.0  17.0       0.0        0.0
# 3        21.15  2.706697        2.0  41.0      13.0        2.0
# 4        51.53  3.861459        1.0  24.0       2.0        1.0
# ..         ...       ...        ...   ...       ...        ...
# 531      20.69  5.223326        2.0  27.0       4.0        0.0
# 532       4.24  3.389884        0.0   7.0       2.0        0.0
# 533       2.89  2.551829        0.0  12.0      12.0        0.0
# 534      40.42  6.286957        1.0  47.0       3.0        2.0
# 535      48.94  4.519987        1.0  11.0      13.0        0.0
#
#                                               geometry  residuals  east  \
# 0    POLYGON ((399848.954 5815619.506, 399854.727 5... -19.688017     1
# 1    POLYGON ((393175.012 5821135.577, 393167.174 5...  -3.633546     1
# 2    POLYGON ((388394.110 5807792.070, 388379.276 5...   0.435593     0
# 3    POLYGON ((396010.552 5819339.570, 396021.567 5...   6.981902     1
# 4    POLYGON ((387367.428 5828619.763, 387315.862 5...  17.408565     1
# ..                                                 ...        ...   ...
# 531  POLYGON ((387280.650 5828614.114, 387266.882 5... -14.019090     0
# 532  POLYGON ((392586.179 5829994.574, 392586.626 5...  -9.762495     1
# 533  POLYGON ((406064.851 5815581.891, 406061.455 5...  -2.560691     1
# 534  POLYGON ((391887.140 5816592.598, 391898.686 5...   9.063653     1
# 535  POLYGON ((395625.330 5821110.205, 395642.331 5...  28.828471     1
#
#      residuals_m2
# 0      -19.952260
# 1       -2.960949
# 2        5.296694
# 3        6.869233
# 4       18.474703
# ..            ...
# 531    -14.254279
# 532    -10.797044
# 533     -3.615019
# 534      5.842273
# 535     27.231019
#
# [536 rows x 16 columns]

# %%
# loading east/west maps
west = gpd.read_file('../raw_data/more_maps/Ortsteile__Berlin_West_EPSG54030.shp')
east = gpd.read_file('../raw_data/more_maps/Ortsteile__Berlin_Ost_EPSG54030.shp')

# adapting projections
east.to_crs(crs='EPSG:25833', inplace=True)
west.to_crs(crs='EPSG:25833', inplace=True)

# dissolving
west = west.dissolve()
east = east.dissolve()

# merging both maps into an eastwest geodataframe
eastwest = east.append(west)

# adding an east column to eastwest geodataframe
eastwest['east'] = eastwest.OBJECTID.map({1:1,
                                             2:0})

eastwest = eastwest[['east','geometry']]

# merging eastwest geodataframe with sample df

selected_east = selected.sjoin_nearest(
    eastwest, how='left').dissolve(
    by='PLR_ID')

selected = selected.merge(selected_east.reset_index()[['PLR_ID','east']], on='PLR_ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [155], in <cell line: 28>()
#      22 # merging eastwest geodataframe with sample df
#      24 selected_east = selected.sjoin_nearest(
#      25     eastwest, how='left').dissolve(
#      26     by='PLR_ID')
# ---> 28 selected = selected.merge(selected_east.reset_index()[['PLR_ID','east']], on='PLR_ID')
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/geopandas/geodataframe.py:1428, in GeoDataFrame.__getitem__(self, key)
#    1422 def __getitem__(self, key):
#    1423     """
#    1424     If the result is a column containing only 'geometry', return a
#    1425     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1426     return a GeoDataFrame.
#    1427     """
# -> 1428     result = super().__getitem__(key)
#    1429     geo_col = self._geometry_column_name
#    1430     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.8.12/envs/school-map-project/lib/python3.8/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['east'] not in index"

# %%
X.shape
# Out:
# (536, 10)

# %%
# Running an OLS Regimes model

m2 = OLS_Regimes(y,
                X,
                w=inv_dist,
                regimes=selected['east'],
                name_y='child_pov',
                name_x=columns,
                name_w='dist',
                name_ds='basic_model',
                white_test=True,
                spat_diag=True,
                moran=True)

# %%
print(m2.summary)
# Out:
# REGRESSION
# ----------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES ESTIMATION - REGIME 0
# ---------------------------------------------------------------
# Data set            : basic_model
# Weights matrix      :        dist
# Dependent Variable  : 0_child_pov                Number of Observations:         195
# Mean dependent var  :     21.2256                Number of Variables   :          11
# S.D. dependent var  :     15.2800                Degrees of Freedom    :         184
# R-squared           :      0.3605
# Adjusted R-squared  :      0.3257
# Sum squared residual:   28966.751                F-statistic           :     10.3717
# Sigma-square        :     157.428                Prob(F-statistic)     :   8.339e-14
# S.E. of regression  :      12.547                Log likelihood        :    -764.281
# Sigma-square ML     :     148.547                Akaike info criterion :    1550.562
# S.E of regression ML:     12.1880                Schwarz criterion     :    1586.565
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#           0_CONSTANT      13.6598380       4.0236599       3.3948789       0.0008410
#            0_culture      -0.1010279       0.4167027      -0.2424460       0.8087046
#         0_outdoor_fa       0.0189991       0.0217443       0.8737479       0.3833945
#         0_outdoor_le       0.1649314       0.1453762       1.1345139       0.2580549
#         0_social_hou       0.6451320       0.3496524       1.8450668       0.0666351
#         0_public_hou       0.5810037       0.1159246       5.0119098       0.0000013
#            0_vegpm20      -1.3024129       0.4321025      -3.0141293       0.0029408
#          0_Gymnasium      -0.6275433       1.0166977      -0.6172369       0.5378416
#               0_kita       0.0866111       0.1166171       0.7426969       0.4586123
#           0_stations      -0.2953910       0.6322922      -0.4671748       0.6409276
#          0_extra_edu      -0.5056242       0.8164499      -0.6192960       0.5364874
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           13.626
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          26.689           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               10          29.972           0.0009
# Koenker-Bassett test             10          20.797           0.0226
#
# SPECIFICATION ROBUST TEST
# TEST                             DF        VALUE           PROB
# White                            65          83.825           0.0581
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.0402         5.616           0.0000
# Lagrange Multiplier (lag)         1           8.519           0.0035
# Robust LM (lag)                   1           4.189           0.0407
# Lagrange Multiplier (error)       1           6.595           0.0102
# Robust LM (error)                 1           2.265           0.1324
# Lagrange Multiplier (SARMA)       2          10.784           0.0046
#
# ----------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES ESTIMATION - REGIME 1
# ---------------------------------------------------------------
# Data set            : basic_model
# Weights matrix      :        dist
# Dependent Variable  : 1_child_pov                Number of Observations:         341
# Mean dependent var  :     26.4362                Number of Variables   :          11
# S.D. dependent var  :     17.1507                Degrees of Freedom    :         330
# R-squared           :      0.3663
# Adjusted R-squared  :      0.3471
# Sum squared residual:   63374.176                F-statistic           :     19.0769
# Sigma-square        :     192.043                Prob(F-statistic)     :   1.253e-27
# S.E. of regression  :      13.858                Log likelihood        :   -1374.708
# Sigma-square ML     :     185.848                Akaike info criterion :    2771.417
# S.E of regression ML:     13.6326                Schwarz criterion     :    2813.568
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#           1_CONSTANT      11.4323669       3.0657123       3.7291063       0.0002261
#            1_culture      -0.0153007       0.1784486      -0.0857431       0.9317226
#         1_outdoor_fa       0.0088971       0.0062171       1.4310619       0.1533588
#         1_outdoor_le      -0.2529016       0.1108737      -2.2809891       0.0231860
#         1_social_hou       1.0210190       0.1561926       6.5369244       0.0000000
#         1_public_hou       0.5184138       0.0676238       7.6661408       0.0000000
#            1_vegpm20      -0.4209247       0.4689195      -0.8976482       0.3700276
#          1_Gymnasium      -0.9555757       1.1701490      -0.8166274       0.4147305
#               1_kita       0.4027904       0.0750824       5.3646473       0.0000002
#           1_stations      -0.7509502       0.1498869      -5.0101113       0.0000009
#          1_extra_edu      -2.1331965       0.6540192      -3.2616727       0.0012233
# ------------------------------------------------------------------------------------
# Regimes variable: unknown
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER           12.593
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2           8.935           0.0115
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               10          11.550           0.3163
# Koenker-Bassett test             10          10.813           0.3722
#
# SPECIFICATION ROBUST TEST
# TEST                             DF        VALUE           PROB
# White                            65          76.075           0.1638
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.0176         3.990           0.0001
# Lagrange Multiplier (lag)         1          16.147           0.0001
# Robust LM (lag)                   1          13.318           0.0003
# Lagrange Multiplier (error)       1           3.354           0.0671
# Robust LM (error)                 1           0.525           0.4687
# Lagrange Multiplier (SARMA)       2          16.672           0.0002
#
#
# REGIMES DIAGNOSTICS - CHOW TEST
#                  VARIABLE        DF        VALUE           PROB
#                  CONSTANT         1           0.194           0.6597
#                 Gymnasium         1           0.045           0.8324
#                   culture         1           0.036           0.8500
#                 extra_edu         1           2.421           0.1197
#                      kita         1           5.197           0.0226
#                outdoor_fa         1           0.200           0.6551
#                outdoor_le         1           5.223           0.0223
#                public_hou         1           0.217           0.6410
#                social_hou         1           0.963           0.3263
#                  stations         1           0.491           0.4833
#                   vegpm20         1           1.911           0.1668
#               Global test        11          16.605           0.1201
#
# DIAGNOSTICS FOR GLOBAL SPATIAL DEPENDENCE
# Residuals are treated as homoskedastic for the purpose of these tests
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.0912        16.150           0.0000
# Lagrange Multiplier (lag)         1         110.119           0.0000
# Robust LM (lag)                   1          54.741           0.0000
# Lagrange Multiplier (error)       1          98.917           0.0000
# Robust LM (error)                 1          43.539           0.0000
# Lagrange Multiplier (SARMA)       2         153.658           0.0000
#
# ================================ END OF REPORT =====================================

# %%
# Adding a resituals column to sample dataframe
res['residuals_m2'] = m2.u

# plotting residuals - red = underestimation, blue = overestimation
res.plot('residuals_m2', figsize=(15,10), cmap= 'seismic', legend=True)
# Out:
# <AxesSubplot:>

# %%
mae(selected.child_pov, m2.predy)
# Out:
# 10.201795823385401

# %%
mse(selected.child_pov, m2.predy)
# Out:
# 172.27784757756328
